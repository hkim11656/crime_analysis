# %%
import numpy as np
import pandas as pd
import matplotlib as mp
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %%
fm = mp.font_manager.FontManager()
plt.rcParams['font.family'] = 'Malgun Gothic'

# %%
df_together = pd.read_excel('./소년범죄자 공범관계.csv')
df_together
# Out:
#       No   자료시점    분류               분류.1               분류.2       계     계.1  \
# 0     No   자료시점    분류                 분류                 분류       계     단독범
# 1     No   자료시점    분류                 분류                 분류       계     단독범
# 2     No   자료시점    분류                 분류                 분류     원자료     원자료
# 3      1  2018년     계             계[입력치]             계[입력치]  66,142  31,713
# 4      2  2018년   형법범          형법범계[입력치]          형법범계[입력치]  54,205  22,845
# ..   ...    ...   ...                ...                ...     ...     ...
# 118  116  2018년  특별법범       풍속영업의규제에관한법률       풍속영업의규제에관한법률       2       0
# 119  117  2018년  특별법범  학원의설립운영및과외교습에관한법률  학원의설립운영및과외교습에관한법률       0       0
# 120  118  2018년  특별법범               예비군법               예비군법       0       0
# 121  119  2018년  특별법범         화물자동차운수사업법         화물자동차운수사업법       0       0
# 122  120  2018년  특별법범              기타특별법              기타특별법     475     273
#
#         계.2     계.3        계.4     계.5     계.6     계.7     계.8     계.9  \
# 0    공범(소계)  공범(소계)     공범(소계)  공범(소계)  공범(소계)  공범(소계)  공범(소계)  공범(소계)
# 1    공범(소계)    학교동창  교도소·소년원친구    직장동료     친인척     군동료    동네친구    고향친구
# 2       원자료     원자료        원자료     원자료     원자료     원자료     원자료     원자료
# 3    27,554   9,543        195      63     234       2  12,711     551
# 4    25,818   9,100        188      46     224       2  11,963     535
# ..      ...     ...        ...     ...     ...     ...     ...     ...
# 118       0       0          0       0       0       0       0       0
# 119       0       0          0       0       0       0       0       0
# 120       0       0          0       0       0       0       0       0
# 121       0       0          0       0       0       0       0       0
# 122     133      15          6       0       1       0      76       3
#
#        계.10    계.11   계.12
# 0    공범(소계)  공범(소계)     미상
# 1        애인      기타     미상
# 2       원자료     원자료    원자료
# 3       471   3,784  6,875
# 4       430   3,330  5,542
# ..      ...     ...    ...
# 118       0       0      2
# 119       0       0      0
# 120       0       0      0
# 121       0       0      0
# 122       2      30     69
#
# [123 rows x 18 columns]

# %%
df_life = df_life.rename(columns={'분류':'대분류', '분류.1':'중분류','분류.2':'소분류','계.1':'하류', '계.2':'중류', '계.3':'상류', '계.4':'미상'})
df_life.head()
