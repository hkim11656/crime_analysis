# %%
import pandas as pd
import matplotlib as mp
import matplotlib.pyplot as plt

# %%
# 데이터 불러오기
df = pd.read_csv('./Data/08_소년범죄 중 5대 강력범죄 비율.csv', sep = ',', thousands=',') 
df.fillna(0, inplace=True)
df.head()
# Out:
#    No   자료시점   분류       분류.1          분류.2   소년(소계)  14세미만     14세      15세  \
# 0   1  2019년    계     계[입력치]        계[입력치]  66247.0    0.0  9053.0  11730.0
# 1   2  2019년  형법범  형법범계[입력치]     형법범계[입력치]  54497.0    0.0  8322.0  10399.0
# 2   3  2019년  형법범       재산범죄  재산범죄의 계[입력치]  27809.0    0.0  5077.0   5802.0
# 3   4  2019년  형법범       재산범죄            배임      1.0    0.0     0.0      0.0
# 4   5  2019년  형법범       재산범죄            사기   8088.0    0.0   609.0   1023.0
#
#        16세      17세      18세
# 0  13548.0  14338.0  17578.0
# 1  11105.0  11090.0  13581.0
# 2   6202.0   5274.0   5454.0
# 3      0.0      0.0      1.0
# 4   1762.0   2044.0   2650.0

# %%
df_all = pd.DataFrame(data= { '분류': df['분류.2'], '범죄자수': df['소년(소계)'] })
df_all = df_all[(~df_all['분류'].str.contains('계'))]
df_all.head()
# Out:
#    분류     범죄자수
# 3  배임      1.0
# 4  사기   8088.0
# 5  손괴   1124.0
# 6  장물    175.0
# 7  절도  17141.0

# %%
# 5대범죄 추출
df_5 = pd.concat([
    df_all[df_all['분류'] == '절도'],
    df_all[df_all['분류'] == '강도'],
    df_all[df_all['분류'] == '살인'],
    df_all[df_all['분류'] == '성폭력'],
])

force = [
    '공갈',
    '상해',
    '약취와 유인',
    '체포와 감금',
    '폭력행위등\(단체등의구성,활동\)',
    '폭력행위등\(손괴,강요,주거침입등\)',
    '폭행',
    '협박',
]


force_count = 0
for f in force:
    df_temp = df_all[df_all['분류'] == f]
    if not df_temp.empty:
        force_count += df_temp.iloc[0]['범죄자수']

df_5 = df_5.append({ '분류': '폭력', '범죄자수': force_count }, ignore_index=True)
df_5
# Out:
#     분류     범죄자수
# 0   절도  17141.0
# 1   강도    366.0
# 2   살인     20.0
# 3  성폭력   3180.0
# 4   폭력  18011.0

# %%
all_count = df_all['범죄자수'].sum()

df_result = df_5.append({ '분류': '기타', '범죄자수': all_count - df_5['범죄자수'].sum() }, ignore_index=True)
df_result
# Out:
#     분류     범죄자수
# 0   절도  17141.0
# 1   강도    366.0
# 2   살인     20.0
# 3  성폭력   3180.0
# 4   폭력  18011.0
# 5   기타  27529.0

# %%
# 그래프 그리기

fm = mp.font_manager.FontManager()
#한글 지원하는 폰트명으로 재할당
plt.rcParams['font.family'] = 'Malgun Gothic'
#plt.rc('font', family='Malgun Gothic')

# %%
ratio = []
labels = []

for i in range(len(df_result)):
    labels.append(df_result.iloc[i]['분류'])
    ratio.append(df_result.iloc[i]['범죄자수'] / all_count * 100)

ratio, labels
# Out:
# ([25.8743792171721,
#   0.5524778480534968,
#   0.030190046341721136,
#   4.80021736833366,
#   27.187646233036965,
#   41.55508928706206],
#  ['절도', '강도', '살인', '성폭력', '폭력', '기타'])

# %%
plt.pie(ratio, labels=labels, autopct='%.1f%%')
plt.show()

# %%
# 데이터 불러오기
df = pd.read_csv('./Data/08_소년범죄 중 5대 강력범죄 비율_2.csv', encoding='cp949') 
df.fillna(0, inplace=True)
df[['죄종별(2)','2019.2','2019.3','2019.4','2019.5','2019.6','2019.7','2019.8','2019.9']]
# df.head()
# Out:
#          죄종별(2) 2019.2 2019.3 2019.4 2019.5 2019.6   2019.7 2019.8 2019.9
# 0        죄종별(2)    미성년    미성년    미성년    미성년    미성년       성년     성년     성년
# 1        죄종별(2)    14세    15세    16세    17세    18세       소계    19세    20세
# 2            소계   9028  11681  13503  14249  17446  1516477  20259  18026
# 3            소계    305    431    463    525    634    26550    693    509
# 4          살인기수      -      -      3      1      5      335      6      -
# 5         살인미수등      2      1      1      3      3      515      6      2
# 6            강도     38     69     84     77     93      974     82     51
# 7       강간·강제추행      -      -      -      -      -        -      -      -
# 8            강간     51    115    122    167    183     5489    226    167
# 9          유사강간     14     25     24     36     41      754     30     35
# 10         강제추행    159    168    179    207    268    16890    296    221
# 11  기타 강간·강제추행등     10     26     23     25     36      375     25     23
# 12           소계   4172   4388   3878   2626   2047    84099   1790   1431
# 13           소계   2475   3475   3598   4050   6040   326411   6694   5469
# 14           상해    291    420    423    573    786    46337    786    662
# 15           폭행    720   1108   1266   1654   2966   194749   3566   2946
# 16        체포·감금      9     25     18     27     43     1523     67     62
# 17           협박     84    110    169    149    160    21661    175    180
# 18        약취·유인      3      -      2      6      9      318      5      6
# 19        폭력행위등   1060   1393   1263   1204   1530    22067   1519   1106
# 20           공갈    172    254    238    221    168     2487    110    100
# 21           손괴    136    165    219    216    378    37269    466    407

# %%
# 전체
df_all = df[df['죄종별(1)'] == '계']
df_all
# Out:
#   죄종별(1) 죄종별(2)     2011 2011.1 2011.2 2011.3 2011.4 2011.5 2011.6 2011.7  \
# 2      계     소계  1815233  86616    316   5454  17834  22791  20774  19447
#
#    ... 2019.11 2019.12 2019.13 2019.14 2019.15 2019.16 2019.17 2019.18  \
# 2  ...  131970  123442  156540  155689  192774  184847  180686  116263
#
#   2019.19 2019.20
# 2   58659   58521
#
# [1 rows x 198 columns]

# %%
# 살인
df_murder = df[df['죄종별(2)'].str.contains('살인')]
df_murder
# Out:
#   죄종별(1) 죄종별(2) 2011 2011.1 2011.2 2011.3 2011.4 2011.5 2011.6 2011.7  ...  \
# 4   강력범죄   살인기수  449      7      -      -      -      2      2      3  ...
# 5   강력범죄  살인미수등  836      5      -      -      1      -      1      3  ...
#
#   2019.11 2019.12 2019.13 2019.14 2019.15 2019.16 2019.17 2019.18 2019.19  \
# 4      26      32      36      30      34      37      44      29      17
# 5      37      41      46      50      73      72      73      45      28
#
#   2019.20
# 4      22
# 5      18
#
# [2 rows x 198 columns]

# %%
# 강도
df_gang = df[df['죄종별(2)'].str.contains('강도')]
df_gang
# Out:
#   죄종별(1) 죄종별(2)  2011 2011.1 2011.2 2011.3 2011.4 2011.5 2011.6 2011.7  ...  \
# 6   강력범죄     강도  4890   1144      -     36    185    284    328    311  ...
#
#   2019.11 2019.12 2019.13 2019.14 2019.15 2019.16 2019.17 2019.18 2019.19  \
# 6     128     111     101      75      95      72      60      32       8
#
#   2019.20
# 6      11
#
# [1 rows x 198 columns]

# %%
# 성범죄
df_gender = df[(df['죄종별(2)'].str.contains('강간')) | df['죄종별(2)'].str.contains('강제추행')]
df_gender
# Out:
#    죄종별(1)       죄종별(2)   2011 2011.1 2011.2 2011.3 2011.4 2011.5 2011.6  \
# 7    강력범죄      강간·강제추행  17652   1883      5     80    280    507    502
# 8    강력범죄           강간      -      -      -      -      -      -      -
# 9    강력범죄         유사강간      -      -      -      -      -      -      -
# 10   강력범죄         강제추행      -      -      -      -      -      -      -
# 11   강력범죄  기타 강간·강제추행등      -      -      -      -      -      -      -
#
#    2011.7  ... 2019.11 2019.12 2019.13 2019.14 2019.15 2019.16 2019.17  \
# 7     509  ...       -       -       -       -       -       -       -
# 8       -  ...     888     617     619     438     416     361     337
# 9       -  ...     103      96      54      75      62      50      44
# 10      -  ...    1866    1529    1724    1559    1922    1841    1625
# 11      -  ...      40      32      48      27      32      28      27
#
#    2019.18 2019.19 2019.20
# 7        -       -       -
# 8      200     100      98
# 9       31      12      18
# 10    1008     655     807
# 11      19       9      10
#
# [5 rows x 198 columns]

# %%
# 절도
df_steal = df[df['죄종별(1)'] == '절도범죄']
df_steal
# Out:
#    죄종별(1) 죄종별(2)    2011 2011.1 2011.2 2011.3 2011.4 2011.5 2011.6 2011.7  \
# 12   절도범죄     소계  111390  32693     63   2796   8700   9644   6671   4819
#
#     ... 2019.11 2019.12 2019.13 2019.14 2019.15 2019.16 2019.17 2019.18  \
# 12  ...    6625    5797    6980    6514    7995    8188    9554    7410
#
#    2019.19 2019.20
# 12    5216    8744
#
# [1 rows x 198 columns]

# %%
# 폭력
df_force = df[(df['죄종별(1)'] == '폭력범죄') & (df['죄종별(2)'] != '소계')]
df_force
# Out:
#    죄종별(1) 죄종별(2)    2011 2011.1 2011.2 2011.3 2011.4 2011.5 2011.6 2011.7  \
# 14   폭력범죄     상해   89138   2695      9    160    457    562    657    850
# 15   폭력범죄     폭행  161782   3591      9    136    427    639    987   1393
# 16   폭력범죄  체포·감금     969     21      1      2      3      3      8      4
# 17   폭력범죄     협박    3855     70      3      3     15     11     21     17
# 18   폭력범죄  약취·유인     340     16      -      -      2      1      4      9
# 19   폭력범죄  폭력행위등  103423  15386     29   1210   3880   4106   3232   2929
# 20   폭력범죄     공갈    3786   1576      -    136    466    491    312    171
# 21   폭력범죄     손괴   28749    452     12     34     56     79    117    154
#
#     ... 2019.11 2019.12 2019.13 2019.14 2019.15 2019.16 2019.17 2019.18  \
# 14  ...    3573    3723    4933    4919    6120    5686    5207    3259
# 15  ...   16270   15857   21487   21022   25246   23182   21778   13115
# 16  ...     152     133     151     138     174     165     161      86
# 17  ...    1403    1592    2325    2518    3230    3147    2832    1652
# 18  ...      30      42      55      41      24      16      27       8
# 19  ...    2533    2004    2142    1733    1985    1675    1485     867
# 20  ...     197     223     240     262     295     302     235     130
# 21  ...    2774    2867    3914    3972    5046    4909    4427    2649
#
#    2019.19 2019.20
# 14    1634    1847
# 15    6242    6201
# 16      43      31
# 17     764     688
# 18      12      22
# 19     422     352
# 20      64      47
# 21    1353    1854
#
# [8 rows x 198 columns]

# %%
def make_dict_from_df_sum(dataframe):
    # 조회기간 : 2011 ~ 2019
    start_year = 2011
    end_year = 2019

    # 세분류 컬럼 갯수
    columns_young = 6 + 1
    columns_old = 13 + 1 + 1

    column_start = 3

    d = {}
    for i in range(len(dataframe)):
        column_index = column_start
        data = dataframe.iloc[i].str.replace('-', '0')

        for y in range(start_year, end_year + 1):

            year = str(y)
            key_young = year + '_young'
            key_old = year + '_old'

            if(d.get(key_young) == None):
                d[key_young] = 0
                
            d[key_young] += int(data[column_index])

            column_index += columns_young

            if(d.get(key_old) == None):
                d[key_old] = 0

            d[key_old] += int(data[column_index])

            column_index += columns_old

    return d

# %%
def make_df_with_sum(dataframe):
    # 조회기간 : 2011 ~ 2019
    start_year = 2011
    end_year = 2019

    # 세분류 컬럼 갯수
    columns_young = 6 + 1
    columns_old = 13 + 1 + 1

    column_start = 3

    
    df_o = pd.DataFrame(columns=range(start_year, end_year + 1))
    
    dict_y = {y : 0 for y in range(start_year, end_year + 1)}
    dict_o = {y : 0 for y in range(start_year, end_year + 1)}


    for i in range(len(dataframe)):
        column_index = column_start
        data = dataframe.iloc[i].str.replace('-', '0')

        for y in range(start_year, end_year + 1):
            # if y == 2019:
                # column_index -= 1

            # print('young', column_index)
                
            dict_y[y] += int(data[column_index])
            column_index += columns_young

            if y == 2018 or y == 2019:
                column_index -= 1


            # print('old', column_index)

            dict_o[y] += int(data[column_index])
            column_index += columns_old

    df_y = pd.DataFrame.from_dict(dict_y, orient='index')
    df_y.columns = ['범죄자수']

    df_o = pd.DataFrame.from_dict(dict_o, orient='index')
    df_o.columns = ['범죄자수']

    return df_y, df_o

# %%
# 연간 소년/성인 전체 집계 추출
df_all_y, df_all_o = make_df_with_sum(df_all)

# 연간 소년/성인 살인 집계 추출
df_murder_y, df_murder_o = make_df_with_sum(df_murder)

# 연간 소년/성인 강도 집계 추출
df_gang_y, df_gang_o = make_df_with_sum(df_gang)

# 연간 소년/성인 성범죄 집계 추출
df_gender_y, df_gender_o = make_df_with_sum(df_gender)

# 연간 소년/성인 절도 집계 추출
df_steal_y, df_steal_o = make_df_with_sum(df_steal)

# 연간 소년/성인 폭력 집계 추출
df_force_y, df_force_o = make_df_with_sum(df_force)

# %%
# 5대범죄 합계 추출
df_5_y = df_murder_y + df_gang_y + df_gender_y + df_steal_y + df_force_y
df_5_o = df_murder_o + df_gang_o + df_gender_o + df_steal_o + df_force_o

# %%
# 5대 소년 강력범죄의 연간 증감추이
(df_5_y / df_all_y * 100).plot(figsize=(15,4), color = 'red')
# Out:
# <AxesSubplot:>

# %%
# 5대 소년 강력범죄의 연간 증감추이
(df_murder_y / df_all_y * 100).plot(figsize=(15,4), color = 'red')
(df_gang_y / df_all_y * 100).plot(figsize=(15,4), color = 'red')
(df_gender_y / df_all_y * 100).plot(figsize=(15,4), color = 'red')
(df_steal_y / df_all_y * 100).plot(figsize=(15,4), color = 'red')
(df_force_y / df_all_y * 100).plot(figsize=(15,4), color = 'red')
# Out:
# <AxesSubplot:>

# %%
df_all_y.plot(figsize=(15,4), color = 'red')
# Out:
# <AxesSubplot:>

# %%
# 5대 성인 강력범죄의 연간 증감추이
(df_5_o / df_all_o * 100).plot(figsize=(15,4), color = 'blue')
# Out:
# <AxesSubplot:>

# %%
murder_rate = df_murder_y.loc[2019] / df_all_y.loc[2019] * 100
gang_rate = df_gang_y.loc[2019] / df_all_y.loc[2019] * 100
gender_rate = df_gender_y.loc[2019] / df_all_y.loc[2019] * 100
steal_rate = df_steal_y.loc[2019] / df_all_y.loc[2019] * 100
foece_rate = df_force_y.loc[2019] / df_all_y.loc[2019] * 100
etc_rate = (df_all_y.loc[2019] - df_5_y.loc[2019]) / df_all_y.loc[2019] * 100

# %%
ratio = [murder_rate[0], gang_rate[0], gender_rate[0], steal_rate[0], foece_rate[0], etc_rate[0]]
labels = ['살인', '강도', '성폭력', '절도', '폭력', '기타']

plt.pie(ratio, labels=labels, autopct='%.1f%%')
plt.show()

# %%
# 전체에서 소년, 성인 5대 강력범죄 비율
all_2019 = df_all_y.loc[2019][0] + df_all_o.loc[2019][0]

y_5_rate = df_5_y.loc[2019] / all_2019 * 100
o_5_rate = df_5_o.loc[2019] / all_2019 * 100
etc_rate = 100 - (y_5_rate + o_5_rate)

y_5_rate, o_5_rate, etc_rate

ratio = [y_5_rate[0], o_5_rate[0], etc_rate[0]]
labels = ['소년5대범죄', '성인5대범죄', '기타']

plt.pie(ratio, labels=labels, autopct='%.1f%%')
plt.show()

# %%
#아래쪽에 5대 범죄를 합쳐서
