# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib as mp
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import seaborn as sns
import re

mp.rcParams['axes.unicode_minus'] = False

# %%
fm = mp.font_manager.FontManager()
plt.rcParams["font.family"] = 'Malgun Gothic'

# %%
pd.set_option('display.max_columns',40)

# %%
df_under = pd.read_csv('./data/12_범죄자 연령(14세 미만 포함)_홍상석1.csv', thousands = ',')
df_under.head()
# Out:
#    No   자료시점   분류       분류.1       분류.2          계     계.1     계.2     계.3  \
# 0  No   자료시점   분류         분류         분류          계  소년(소계)  소년(소계)  소년(소계)
# 1  No   자료시점   분류         분류         분류          계  소년(소계)   14세미만     14세
# 2  No   자료시점   분류         분류         분류        원자료     원자료     원자료     원자료
# 3   1  2014년    계     계[입력치]     계[입력치]  1,879,548  77,594      37   9,712
# 4   2  2014년  형법범  형법범계[입력치]  형법범계[입력치]    949,859  63,145      27   8,888
#
#       계.4     계.5     계.6     계.7        계.8     계.9    계.10    계.11    계.12  \
# 0  소년(소계)  소년(소계)  소년(소계)  소년(소계)     성인(소계)  성인(소계)  성인(소계)  성인(소계)  성인(소계)
# 1     15세     16세     17세     18세     성인(소계)     19세     20세     21세     22세
# 2     원자료     원자료     원자료     원자료        원자료     원자료     원자료     원자료     원자료
# 3  14,041  16,940  17,517  19,347  1,773,556  20,742  15,900  18,544  22,915
# 4  12,268  13,552  13,621  14,789    870,746  15,201  10,972  11,959  13,789
#
# ...

# %%
df_under = df_under.rename(columns={'분류':'대분류', '분류.1':'중분류','분류.2':'소분류','계':'총합계','계.1':'소년(소계)',
                                    '계.2':'14세미만','계.8':'성인(소계)','계.25':'미상'})

# %%
df_under = df_under.drop(['No','계.3','계.4','계.5','계.6','계.7','계.9','계.10','계.11','계.12','계.13','계.14','계.15',
                          '계.16','계.17','계.18','계.19','계.20','계.21','계.22','계.23','계.24'], axis='columns')

# %%
df_under = df_under.drop(index = [0,1,2])

# %%
df_under.head()
# Out:
#     자료시점  대분류        중분류           소분류        총합계  소년(소계) 14세미만     성인(소계)  \
# 3  2014년    계     계[입력치]        계[입력치]  1,879,548  77,594    37  1,773,556
# 4  2014년  형법범  형법범계[입력치]     형법범계[입력치]    949,859  63,145    27    870,746
# 5  2014년  형법범       재산범죄  재산범죄의 계[입력치]    411,083  36,271     6    367,782
# 6  2014년  형법범       재산범죄            배임     11,740       3     0     10,980
# 7  2014년  형법범       재산범죄            사기    232,827   7,251     3    221,150
#
#        미상
# 3  28,398
# 4  15,968
# 5   7,030
# 6     757
# 7   4,426

# %% [markdown]
# # 자료시점 '년'을 삭제해야함

# %%
thousands = ['자료시점', '총합계', '소년(소계)', '14세미만', '성인(소계)', '미상']
 
for thousand in thousands:
    df_under[thousand]=df_under[thousand].str.replace(',','')

# %%
df_under['자료시점'] = df_under['자료시점'].astype(float)
df_under['총합계'] = df_under['총합계'].astype(float)
df_under['소년(소계)'] = df_under['소년(소계)'].astype(float)
df_under['14세미만'] = df_under['14세미만'].astype(float)
df_under['성인(소계)'] = df_under['성인(소계)'].astype(float)
df_under['미상'] = df_under['미상'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-a2a76213e6c4> in <module>
# ----> 1 df_under['자료시점'] = df_under['자료시점'].astype(float)
#       2 df_under['총합계'] = df_under['총합계'].astype(float)
#       3 df_under['소년(소계)'] = df_under['소년(소계)'].astype(float)
#       4 df_under['14세미만'] = df_under['14세미만'].astype(float)
#       5 df_under['성인(소계)'] = df_under['성인(소계)'].astype(float)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5875         else:
#    5876             # else, only a single dtype is given
# -> 5877             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5878             return self._constructor(new_data).__finalize__(self, method="astype")
#    5879
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
# ...

# %%
pd.set_option('display.max_rows',1000)

# %%
df_und2 = df_under[df_under["대분류"].str.contains("계", case=False, na=True)].copy()
df_und2
# Out:
#       자료시점 대분류     중분류     소분류      총합계 소년(소계) 14세미만   성인(소계)     미상
# 3    2014년   계  계[입력치]  계[입력치]  1879548  77594    37  1773556  28398
# 177  2015년   계  계[입력치]  계[입력치]  1948966  71035    64  1817924  60007
# 351  2016년   계  계[입력치]  계[입력치]  2020196  76000    84  1897655  46541
# 525  2017년   계  계[입력치]  계[입력치]  1861796  72759    93  1745478  43559
# 699  2018년   계  계[입력치]  계[입력치]  1749459  66142   NaN  1637944  45373
# 873  2019년   계  계[입력치]  계[입력치]  1754808  66247   NaN  1657252  31309
